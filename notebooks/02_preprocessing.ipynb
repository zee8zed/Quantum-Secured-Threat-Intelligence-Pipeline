# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print("Current folder:", Path.cwd())
print("Project root:", PROJECT_ROOT)
print("src exists:", (PROJECT_ROOT / "src").exists())
# Out:
# Current folder: /Users/zaidashraf/Quantum-Secured-Threat-Intelligence-Pipeline/notebooks
# Project root: /Users/zaidashraf/Quantum-Secured-Threat-Intelligence-Pipeline
# src exists: True

# %%
import importlib
import src.tokenizer

importlib.reload(src.tokenizer)

from src.tokenizer import preprocess_report

# %%
sample_text = """
APT29 used PowerShell to exploit CVE-2023-38831.
The activity mapped to T1059.001 and contacted 192.168.1.25.
"""

preprocessed = preprocess_report(sample_text)
preprocessed
# Out:
# {'original_text': '\nAPT29 used PowerShell to exploit CVE-2023-38831.\nThe activity mapped to T1059.001 and contacted 192.168.1.25.\n',
#  'cleaned_text': 'APT29 used PowerShell to exploit CVE-2023-38831. The activity mapped to T1059.001 and contacted 192.168.1.25.',
#  'tokens': ['APT29',
#   'used',
#   'PowerShell',
#   'to',
#   'exploit',
#   'CVE-2023-38831.',
#   'The',
#   'activity',
#   'mapped',
#   'to',
#   'T1059.001',
#   'and',
#   'contacted',
#   '192.168.1.25.'],
#  'character_count': 109,
#  'token_count': 14}
